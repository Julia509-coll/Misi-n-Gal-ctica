# %% [markdown]
# # 🚀 Misión Galáctica — Fundamentos Python (ALUMNO)
#
# Versión para practicar: retos claros, pistas y checks rápidos.

# %% [markdown]
# ## Cómo usar este cuaderno
# 1. Completa el código en cada reto.
# 2. Ejecuta el check si existe.
# 3. Si falla, corrige y vuelve a intentar.

# %%
from IPython.display import HTML, display
display(HTML("<div style='padding:10px;border-radius:10px;background:#1f2937;color:#fff'>🛰️ Iniciando entrenamiento de la tripulación...</div>"))
# Out:
# <div style='padding:10px;border-radius:10px;background:#1f2937;color:#fff'>🛰️ Iniciando entrenamiento de la tripulación...</div>

# %% [markdown]
# ## Reto 1 — Variables y tipos
# Crea estas variables: `capitana` (texto), `energia` (número), `escudo_activo` (booleano).

# %%
# TODO
capitana = 'Julia'
energia = 100
escudo_activo = True
print(capitana, energia, escudo_activo)
# Out:
# Elena Vega 100 True

# %%
assert isinstance(capitana, str), 'Julia'
assert isinstance(energia, (int, float)), '100'
assert isinstance(escudo_activo, bool), 'True'
print('✅ Reto 1 OK')
# Out:
# ✅ Reto 1 OK

# %% [markdown]
# ## Reto 2 — Condicionales
# Muestra `Aterrizaje autorizado` si `energia >= 40` y `escudo >= 50`; si no, denegado.

# %%
energia = 45
escudo = 60
# TODO: escribe aquí el if/else

if energia >= 40 and escudo >= 50:
     print ("Aterrizaje_autorizado")
    
else:
     print("Aterrizaje denegado")
# Out:
# Aterrizaje_autorizado

# %% [markdown]
# ## Reto 3 — Bucles
# Recorre `modulos` y muestra `Revisando <modulo>...`

# %%
modulos = ['motor', 'radar', 'escudos', 'comunicaciones']
# TODO: for ...

# %%
# 1. Creamos la lista de módulos
modulos = ['motor', 'radar', 'escudos', 'comunicaciones']

# 2. Usamos el bucle para recorrerlos
for sistema in modulos:
    # 'sistema' es una variable temporal que va cambiando en cada vuelta
    print(f"Revisando {sistema}...")
# Out:
# Revisando motor...
# Revisando radar...
# Revisando escudos...
# Revisando comunicaciones...

# %% [markdown]
# ## Reto 4 — Funciones
# Completa `puntos_mision` para que devuelva `tareas*10 + bonus`.

# %%
def puntos_mision(tareas, bonus):
    # TODO
    return 0

print('Puntos:', puntos_mision(6, 12))
def puntos_mision(tareas, bonus):
    # 1. Calculamos el total siguiendo la regla
    total = (tareas * 10) + bonus
    return total # Sacamos el valor al exterior

# --- AQUÍ EMPIEZA EL "EXTERIOR" (Sin espacios al principio) ---

# Usamos la función y guardamos lo que "escupe" en una variable nueva
mi_puntuacion = puntos_mision(2, 5)

# Ahora imprimimos la variable de fuera, NO la de dentro
print(mi_puntuacion)
# Out:
# Puntos: 0
# 25

# %%
assert puntos_mision(2, 5) == 25, 'Revisa la fórmula de la función'
print('✅ Reto 4 OK')
# Out:
# ✅ Reto 4 OK

# %% [markdown]
# ## Reto 5 — Diccionarios
# Crea un diccionario `pilota` con `nombre`, `rol`, `nivel` y muestra nombre + rol.

# %%
# TODO
pilota = {}
# TODO: imprime nombre y rol

# %%
# 1. Creamos el diccionario con llaves { }
pilota = {
    "nombre": "Sonia",
    "rol": "Piloto de combate",
    "nivel": 17
}

# 2. Imprimimos para comprobar que funciona
print(f"Pilota: {pilota['nombre']} | Nivel: {pilota['nivel']}")

# 3. La prueba de fuego del ejercicio
assert pilota['nombre'] == 'Sonia'
print('✅ Reto 5 OK')
# Out:
# Pilota: Sonia | Nivel: 17
# ✅ Reto 5 OK

# %% [markdown]
# ## Reto 6 (creativo) — Barra de progreso
# Asigna un valor a `progreso` (0-100) y visualiza una barra.

# %%
# 1. Definimos las variables de estado
energia = 45
escudo = 60
# 2. Comprobamos si AMBAS condiciones son seguras
# Necesitamos al menos 40 de energía Y 50 de escudo
if energia >= 40 and escudo >= 50:
    print("Aterrizaje autorizado")
else:
    print("Aterrizaje denegado")

# 3. La comprobación del ejercicio
assert energia >= 40 and escudo >= 50
print('✅ Reto 6 OK')
# Out:
# Aterrizaje autorizado
# ✅ Reto 6 OK

# %% [markdown]
# ## Reto 7 (humor) — Ruleta galáctica
# Usa `random.choice` para escoger un planeta y mostrar un mensaje.

# %%
import random
planetas = ['🪐 Saturno', '🔴 Marte', '🌕 Luna', '🌌 Nebulosa X']
# TODO: elige destino y muestra mensaje


import random
planetas = ['🪐 Saturno', '🔴 Marte', '🌕 Luna', '🌌 Nebulosa X']

# 1. Usamos random.choice para elegir uno de la lista al azar
destino_elegido = random.choice(planetas)

# 2. Mostramos el mensaje con la f-string que ya conoces
print(f"🚀 Destino seleccionado para hoy: {destino_elegido}")

# 3. Verificamos que el destino esté en nuestra lista
assert destino_elegido in planetas
print('✅ Reto 7 OK')
# Out:
# 🚀 Destino seleccionado para hoy: 🪐 Saturno
# ✅ Reto 7 OK

# %% [markdown]
# ## Meta final
# Si completas los 7 retos, ya tienes base para entrar con más seguridad en pandas y limpieza de datos. ✅
